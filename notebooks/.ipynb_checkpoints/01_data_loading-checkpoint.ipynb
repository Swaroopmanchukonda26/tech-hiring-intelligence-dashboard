# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %%
# Load Layoffs Dataset
layoffs = pd.read_csv('../data/raw/layoffs/layoffs.csv')

print("✅ Layoffs dataset loaded!")
print("Shape:", layoffs.shape)
layoffs.head()
# Out:
# ✅ Layoffs dataset loaded!
# Shape: (4428, 11)
#        company             location  total_laid_off       date  \
# 0  SentinelOne          SF Bay Area           230.0  5/29/2026
# 1        Rapyd   Tel Aviv, Non-U.S.             NaN  5/28/2026
# 2       NetApp          SF Bay Area            77.0  5/27/2026
# 3   Lightricks  Jerusalem, Non-U.S.             NaN  5/27/2026
# 4      Webflow          SF Bay Area             NaN  5/27/2026
#
#    percentage_laid_off   industry  \
# 0                 0.08   Security
# 1                  NaN    Finance
# 2                  NaN       Data
# 3                  NaN   Consumer
# 4                  NaN  Marketing
#
#                                               source     stage  funds_raised  \
# 0  https://www.calcalistech.com/ctechnews/article...  Post-IPO         696.0
# 1  https://www.calcalistech.com/ctechnews/article...   Unknown         770.0
# 2  https://hoodline.com/2026/05/san-jose-mainstay...  Post-IPO           NaN
# ...

# %%
# Load Student Placement Dataset
placement = pd.read_csv('../data/raw/dataset 2/student_placement_synthetic.csv')

print("✅ Placement dataset loaded!")
print("Shape:", placement.shape)
placement.head()
# Out:
# ✅ Placement dataset loaded!
# Shape: (100000, 18)
#      branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 0       ECE       Tier-3  6.70         0            7.6        4.4
# 1  Chemical       Tier-2  5.70         0            5.4        7.9
# 2        EE       Tier-2  7.19         0            5.6        6.8
# 3        CE       Tier-2  6.48         0            5.2        3.1
# 4       CSE       Tier-2  6.71         1            5.9        4.7
#
#    aptitude_score  communication_skills  ml_knowledge  system_design  \
# 0            49.5                   3.7           6.4            0.3
# 1            72.0                   8.3           6.3            1.9
# 2            79.1                   7.4           4.4            5.2
# 3            48.4                   5.0           1.1            6.7
# 4            61.2                   4.3           2.7            2.8
#
#    internships  projects_count  certifications  hackathons  \
# ...

# %%
# Load IBM HR Attrition Dataset
hr = pd.read_csv('../data/raw/IBM dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv')

print("✅ IBM HR dataset loaded!")
print("Shape:", hr.shape)
hr.head()
# Out:
# ✅ IBM HR dataset loaded!
# Shape: (1470, 35)
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
print("=" * 50)
print("📊 DATASET SUMMARY")
print("=" * 50)

print(f"\n🔴 Layoffs Dataset:")
print(f"   Rows: {layoffs.shape[0]}")
print(f"   Columns: {layoffs.shape[1]}")
print(f"   Columns: {list(layoffs.columns)}")

print(f"\n🟡 Placement Dataset:")
print(f"   Rows: {placement.shape[0]}")
print(f"   Columns: {placement.shape[1]}")
print(f"   Columns: {list(placement.columns)}")

print(f"\n🟢 IBM HR Dataset:")
print(f"   Rows: {hr.shape[0]}")
print(f"   Columns: {hr.shape[1]}")
print(f"   Columns: {list(hr.columns)}")
# Out:
# ...
# 📊 DATASET SUMMARY
# ...
#
# 🔴 Layoffs Dataset:
#    Rows: 4428
#    Columns: 11
#    Columns: ['company', 'location', 'total_laid_off', 'date', 'percentage_laid_off', 'industry', 'source', 'stage', 'funds_raised', 'country', 'date_added']
#
# 🟡 Placement Dataset:
#    Rows: 100000
#    Columns: 18
#    Columns: ['branch', 'college_tier', 'cgpa', 'backlogs', 'coding_skills', 'dsa_score', 'aptitude_score', 'communication_skills', 'ml_knowledge', 'system_design', 'internships', 'projects_count', 'certifications', 'hackathons', 'open_source_contributions', 'extracurriculars', 'placement_status', 'salary_package_lpa']
#
# 🟢 IBM HR Dataset:
#    Rows: 1470
#    Columns: 35
# ...
